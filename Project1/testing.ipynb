# %%
import pandas as pd

df = pd.read_csv('songData.csv')
df
# Out:
#                                    Song.Name               Song.Length
# 0                                     TOMBOY                      2:54  \
# 1                              Never Stop Me                      2:24
# 2                               VILLAIN DIES                      3:04
# 3                                    ALREADY                      3:21
# 4                                   POLAROID                      3:38
# ...                                      ...                       ...
# 58991              Together (feat. Gavin .D)                      2:50
# 58992                     CÔNG (dance remix)  Add lyrics on Musixmatch
# 58993                           Lava (Remix)                      5:00
# 58994  Loi Thinh Cau (feat. Mino & the Band)  Add lyrics on Musixmatch
# 58995        Bet On Me - ASIA RISING FOREVER                      3:04
#
#                                                Album    Artist
# ...

# %%
print(df["Artist"].unique())
# Out:
# ['(G)I-dle' 'Dreamcatcher' 'Everglow' 'IZ*ONE' 'Mamamoo' 'ITZY' 'CLC'
#  'Twice' 'Blackpink' 'Kard' 'Loona' 'Red Velvet' 'Ikon' 'Chungha'
#  'K.A.R.D' 'GFriend' 'K/DA' 'TOMORROW X TOGETHER' 'LOONA 1/3'
#  'Dreamcather' 'Stray Kids' 'BTS' 'ATEEZ' 'Aespa' 'Solar' 'DreamNote'
#  'Soojin' 'Rose' 'ONEUS' 'Cherry Bullet' 'STAYC' 'Fromis_9' 'BVNDIT' '3YE'
#  'Little Mix' 'MoonByul' 'Girls’ Generation' 'Sumni' 'FIFTY FIFTY' 'JISOO'
#  'NMIXX' 'EXO' 'Day6' '(G)I-DLE' 'Odd eye circle' 'GWSN' 'Weki Meki'
#  'Weeekly' 'Cignature' 'MOMOLAND' 'Purple Kiss' 'HINAPIA' 'April' 'X1'
#  'ANS' 'Cix' 'PIXY' 'BOL4' 'ENHYPEN' 'Rolling Quartz' 'PinkFantasy'
#  'NiziU' 'Ace' 'ONEWE' 'WJSN' 'Golden Child' 'Sunmi' 'Hwasa' 'RM' 'SuperM'
#  'SEVENTEEN' 'Nct 127' 'WooSung' 'LE SSERAFIM' 'NewJeans' 'IVE' 'EXID'
#  'SVT' 'CHUNG HA' 'IU' 'Kpop' 'Hyuna' 'Hyolyn' 'SULLI' 'APink' 'Jessi'
#  'SOYEON' 'CL' '2NE1' 'Aoa' 'Spica' 'Ladies Code' 'Bolbbalgan4' '9MUSES'
# ...
