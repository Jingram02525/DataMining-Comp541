# %%
import pandas as pd

df = pd.read_csv('songData.csv')
df
# Out:
#                    Song.Name Song.Length  \
# 0                    Welcome        3:47
# 1            Age of Aquarius        8:09
# 2                     Part V       10:01
# 3             Dance of Night        8:46
# 4                    Arrival        2:26
# ...                      ...         ...
# 200830         I Will Follow        5:28
# 200831              Twilight        4:21
# 200832        Out of Control        6:30
# 200833  11 O'Clock Tick Tock        3:59
# 200834             The Ocean        3:24
#
#                                                     Album  \
# 0                                         Age Of Aquarius
# 1                                         Age Of Aquarius
# 2                                         Age Of Aquarius
# 3                                         Age Of Aquarius
# 4                                         Age Of Aquarius
# ...                                                   ...
# ...

# %%
print(df["Artist"].unique())
# Out:
# ['Villagers of Ioannina City' 'Black Hat Bones' 'Transidelia'
#  'Thrax Punks' 'Alkinoos Ioannidis' 'MOLYBARON' 'Nikos Ksilouris'
#  'Slomosa' '1000mods' 'Pyx Lax' 'Sun of Nothing' 'Sokratis Malamas'
#  'Nightstalker' 'Ohhms' 'Anser' 'Leo Moracchioli' 'Mephorash' 'Monkey3'
#  'Sleepwulf' 'Yatha Sidra' 'Manos Hadjidakis' 'My Sleeping Karma'
#  'Silent Island' 'Diagonal' 'Obsidian Gate' 'Blackbraid'
#  'Daliborovo Granje' 'Universe217' 'Ganga' 'Planet Of Zeus'
#  'Pavlos Sidiropoulos' 'Frayle' 'Khonsu' 'Socrates' 'Papakonstantinou'
#  'Swan Valley Heights' 'Giannis Kotsiras' 'Locomondo' 'Hashiya'
#  'The Faith And The Muse' 'Thanasis papakonstantinou'
#  'Youngblood Supercult' 'Those Who Ride With Giants' 'Aphrodites Child'
#  'Magick Brother & Mystic Sister' 'Osjan' 'Natural Acoustic Band' 'Atman'
#  'Quintessence' 'Orient Expressions' 'Manson Family' 'Zaum'
#  'Daemonia Nymphe' 'Suns Of Arqa' 'David And Steve Gordon'
# ...
