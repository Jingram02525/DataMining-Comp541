# %%
import pandas as pd

df = pd.read_csv('songData.csv')
df
# Out:
#              Song.Name Song.Length              Album           Artist
# 0               TOMBOY        2:54        I NEVER DIE         (G)I-dle  \
# 1        Never Stop Me        2:24        I NEVER DIE         (G)I-dle
# 2         VILLAIN DIES        3:04        I NEVER DIE         (G)I-dle
# 3              ALREADY        3:21        I NEVER DIE         (G)I-dle
# 4             POLAROID        3:38        I NEVER DIE         (G)I-dle
# ...                ...         ...                ...              ...
# 55248     Tears Of Joy        5:20  Nekrolog 43 Redux  Diary of Dreams
# 55249        UnWanted?        4:19  Nekrolog 43 Redux  Diary of Dreams
# 55250  Congratulations        6:41  Nekrolog 43 Redux  Diary of Dreams
# 55251           AlLone        4:09  Nekrolog 43 Redux  Diary of Dreams
# 55252       The Valley        6:40  Nekrolog 43 Redux  Diary of Dreams
#
#        Date.Released                                               Tags
# ...
