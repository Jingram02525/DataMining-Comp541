# %%
import pandas as pd

df = pd.read_csv('songData.csv')
df
# Out:
#                        Song.Name               Song.Length  \
# 0                        Welcome                      3:47
# 1                Age of Aquarius                      8:09
# 2                         Part V                     10:01
# 3                 Dance of Night                      8:46
# 4                        Arrival                      2:26
# ...                          ...                       ...
# 27551                      Raver                      2:24
# 27552  STUCKINMYHEAD! [Explicit]  Add lyrics on Musixmatch
# 27553           RAVER [Explicit]  Add lyrics on Musixmatch
# 27554  Encore un soir [Explicit]  Add lyrics on Musixmatch
# 27555             Encore un soir                      3:33
#
#                                    Album                      Artist  \
# 0                        Age Of Aquarius  Villagers of Ioannina City
# 1                        Age Of Aquarius  Villagers of Ioannina City
# ...

# %%
dupe_rows = df[df.duplicated(keep=False)]
print(dupe_rows)
