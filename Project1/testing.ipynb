# %%
import pandas as pd

df = pd.read_csv('songData.csv')
df
# Out:
#                                    Song.Name               Song.Length
# 0                Out Of The Black [Explicit]  Add lyrics on Musixmatch  \
# 1                               Come on Over                      2:51
# 2                              Figure It Out                      3:07
# 3                        You Can Be So Cruel                      2:44
# 4                                Blood Hands                      3:07
# ..                                       ...                       ...
# 840     Did Don't Do (feat. Cosmo Sheldrake)                      4:04
# 841                             Echolocation                      4:23
# 842  Rich (feat. Andrea Vargas) [Radio Edit]                      2:32
# 843        Rich (Edit) [feat. Andrea Vargas]                      2:32
# 844                             Echolocation                      4:23
#
#                                                 Album           Artist
# ...
