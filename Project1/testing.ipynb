# %%
import pandas as pd

df = pd.read_csv('songData.csv')
df
# Out:
#                                    Song.Name Song.Length
# 0                              Linger Longer        5:36  \
# 1                                    Wriggle        4:28
# 2                             birth a basket        2:39
# 3                              Birthday Suit        1:13
# 4                                 Come Along        4:19
# ..                                       ...         ...
# 233     Did Don't Do (feat. Cosmo Sheldrake)        4:04
# 234                             Echolocation        4:23
# 235  Rich (feat. Andrea Vargas) [Radio Edit]        2:32
# 236        Rich (Edit) [feat. Andrea Vargas]        2:32
# 237                             Echolocation        4:23
#
#                                                 Album           Artist
# 0                         The Much Much How How and I  Cosmo Sheldrake  \
# 1                         The Much Much How How and I  Cosmo Sheldrake
# ...
