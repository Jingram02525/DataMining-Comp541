# %%
import pandas as pd

df = pd.read_csv('songData.csv')
df
# Out:
#                              Song.Name Song.Length
# 0                               TOMBOY        2:54  \
# 1                        Never Stop Me        2:24
# 2                         VILLAIN DIES        3:04
# 3                              ALREADY        3:21
# 4                             POLAROID        3:38
# ...                                ...         ...
# 8476           Wanna Be (Instrumental)        3:09
# 8477                 SUNRISE -JP ver.-        3:41
# 8478                        La pam pam        3:38
# 8479  SUNRISE -JP ver.- (instrumental)        3:36
# 8480         La pam pam (instrumental)        3:38
#
#                                           Album    Artist    Date.Released
# 0                                   I NEVER DIE  (G)I-dle    14 March 2022  \
# 1                                   I NEVER DIE  (G)I-dle    14 March 2022
# 2                                   I NEVER DIE  (G)I-dle    14 March 2022
# ...
